# %%
from hanzipy.decomposer import HanziDecomposer
from hanzipy.dictionary import HanziDictionary

decomposer = HanziDecomposer()
dictionary = HanziDictionary()

print('Ready:', type(decomposer).__name__, type(dictionary).__name__)
# Out:
# INFO:root:Done compiling 12040 characters
# DEBUG:root:Compiling hanzi characters dictionary...
# DEBUG:root:Starting to read frequency data
# DEBUG:root:Frequency data loaded
# Ready: HanziDecomposer HanziDictionary

# %% [markdown]
# ## Dictionary functions
# Try `definition_lookup`, `dictionary_search`, `get_pinyin`, and examples.

# %%
# definition_lookup() returns a list of dictionary entries
dictionary.definition_lookup('大人')
# Out:
# [{'traditional': '大人',
#   'simplified': '大人',
#   'pinyin': 'da4 ren5',
#   'definition': 'adult/grownup/title of respect toward superiors'}]

# %%
# dictionary_search() finds occurrences/compounds containing the query
results = dictionary.dictionary_search('听')
len(results), results[:5]
# Out:
# (138,
#  [{'traditional': '不問就聽不到假話',
#    'simplified': '不问就听不到假话',
#    'pinyin': 'bu4 wen4 jiu4 ting1 bu4 dao4 jia3 hua4',
#    'definition': "Don't ask and you won't be told any lies. (idiom)"},
#   {'traditional': '不聽命',
#    'simplified': '不听命',
#    'pinyin': 'bu4 ting1 ming4',
#    'definition': 'to disobey'},
#   {'traditional': '不聽老人言，吃虧在眼前',
#    'simplified': '不听老人言，吃亏在眼前',
#    'pinyin': 'bu4 ting1 lao3 ren2 yan2 , chi1 kui1 zai4 yan3 qian2',
#    'definition': '(idiom) ignore your elders at your peril'},
#   {'traditional': '且聽下回分解',
#    'simplified': '且听下回分解',
#    'pinyin': 'qie3 ting1 xia4 hui2 fen1 jie3',
#    'definition': 'to listen to the next chapter for an explanation'},
#   {'traditional': '中聽',
#    'simplified': '中听',
#    'pinyin': 'zhong1 ting1',
#    'definition': "pleasant to hear (i.e. agreeable news)/to one's liking/music to one's ears/Taiwan pr. [zhong4 ting1]"}])

# %%
# get_pinyin() returns all possible pinyin readings for a single character
dictionary.get_pinyin('本')
# Out:
# ['ben3']

# %%
# get_examples() groups example words by frequency buckets
dictionary.get_examples('听')
# Out:
# {'high_frequency': [{'traditional': '听',
#    'simplified': '听',
#    'pinyin': 'yin3',
#    'definition': 'smile (archaic)'},
#   {'traditional': '聽',
#    'simplified': '听',
#    'pinyin': 'ting1',
#    'definition': 'to listen/to hear/to obey/a can (loanword from English "tin")/classifier for canned beverages'},
#   {'traditional': '聽',
#    'simplified': '听',
#    'pinyin': 'ting4',
#    'definition': '(literary pronunciation, still advocated in Taiwan) to rule/to sentence/to allow'}],
#  'mid_frequency': [{'traditional': '傾聽',
#    'simplified': '倾听',
#    'pinyin': 'qing1 ting1',
#    'definition': 'to listen attentively'},
#   {'traditional': '好聽',
#    'simplified': '好听',
#    'pinyin': 'hao3 ting1',
#    'definition': 'pleasant to hear'},
#   {'traditional': '收聽',
#    'simplified': '收听',
#    'pinyin': 'shou1 ting1',
#    'definition': 'to listen to (a radio broadcast)'},
#   {'traditional': '竊聽',
#    'simplified': '窃听',
#    'pinyin': 'qie4 ting1',
#    'definition': 'to eavesdrop/to wiretap'},
#   {'traditional': '聆聽',
#    'simplified': '聆听',
#    'pinyin': 'ling2 ting1',
#    'definition': 'to listen (respectfully)'},
#   {'traditional': '聽到',
#    'simplified': '听到',
#    'pinyin': 'ting1 dao4',
#    'definition': 'to hear'},
#   {'traditional': '聽力',
#    'simplified': '听力',
#    'pinyin': 'ting1 li4',
#    'definition': 'hearing/listening ability'},
#   {'traditional': '聽見',
#    'simplified': '听见',
#    'pinyin': 'ting1 jian4',
#    'definition': 'to hear'},
#   {'traditional': '聽話',
#    'simplified': '听话',
#    'pinyin': 'ting1 hua4',
#    'definition': 'to do what one is told/obedient'},
#   {'traditional': '聽說',
#    'simplified': '听说',
#    'pinyin': 'ting1 shuo1',
#    'definition': 'to hear (sth said)/one hears (that)/hearsay/listening and speaking'}],
#  'low_frequency': [{'traditional': '中聽',
#    'simplified': '中听',
#    'pinyin': 'zhong1 ting1',
#    'definition': "pleasant to hear (i.e. agreeable news)/to one's liking/music to one's ears/Taiwan pr. [zhong4 ting1]"},
#   {'traditional': '任聽',
#    'simplified': '任听',
#    'pinyin': 'ren4 ting1',
#    'definition': 'to allow (sb to act arbitrarily)/to let sb have his head'},
#   {'traditional': '偷聽',
#    'simplified': '偷听',
#    'pinyin': 'tou1 ting1',
#    'definition': 'to eavesdrop/to monitor (secretly)'},
#   {'traditional': '傾聽者',
#    'simplified': '倾听者',
#    'pinyin': 'qing1 ting1 zhe3',
#    'definition': 'listener'},
#   {'traditional': '助聽器',
#    'simplified': '助听器',
#    'pinyin': 'zhu4 ting1 qi4',
#    'definition': 'hearing aid'},
#   {'traditional': '動聽',
#    'simplified': '动听',
#    'pinyin': 'dong4 ting1',
#    'definition': 'pleasant to listen to'},
#   {'traditional': '危言聳聽',
#    'simplified': '危言耸听',
#    'pinyin': 'wei1 yan2 song3 ting1',
#    'definition': 'frightening words to scare people (idiom); alarmist talk/reds under the beds'},
#   {'traditional': '娓娓動聽',
#    'simplified': '娓娓动听',
#    'pinyin': 'wei3 wei3 dong4 ting1',
#    'definition': 'to speak in a pleasant and captivating manner (idiom)'},
#   {'traditional': '打聽',
#    'simplified': '打听',
#    'pinyin': 'da3 ting5',
#    'definition': 'to ask about/to make some inquiries/to ask around'},
#   {'traditional': '探聽',
#    'simplified': '探听',
#    'pinyin': 'tan4 ting1',
#    'definition': 'to make inquiries/to try to find out/to pry'},
#   {'traditional': '接聽',
#    'simplified': '接听',
#    'pinyin': 'jie1 ting1',
#    'definition': 'to answer the phone'},
#   {'traditional': '旁聽',
#    'simplified': '旁听',
#    'pinyin': 'pang2 ting1',
#    'definition': 'to sit in on (proceedings)/to be present at a meeting as an observer/to audit (a class)'},
#   {'traditional': '洗耳恭聽',
#    'simplified': '洗耳恭听',
#    'pinyin': 'xi3 er3 gong1 ting1',
#    'definition': 'to listen with respectful attention/(a polite request to sb to speak)/we are all ears'},
#   {'traditional': '百聽不厭',
#    'simplified': '百听不厌',
#    'pinyin': 'bai3 ting1 bu4 yan4',
#    'definition': 'worth hearing a hundred times'},
#   {'traditional': '監聽',
#    'simplified': '监听',
#    'pinyin': 'jian1 ting1',
#    'definition': 'to monitor/to listen in/to eavesdrop'},
#   {'traditional': '竊聽器',
#    'simplified': '窃听器',
#    'pinyin': 'qie4 ting1 qi4',
#    'definition': 'tapping device/bug'},
#   {'traditional': '聳人聽聞',
#    'simplified': '耸人听闻',
#    'pinyin': 'song3 ren2 ting1 wen2',
#    'definition': 'to sensationalize (idiom); deliberate exaggeration to scare people'},
#   {'traditional': '聽之任之',
#    'simplified': '听之任之',
#    'pinyin': 'ting1 zhi1 ren4 zhi1',
#    'definition': 'to take a laissez-faire attitude'},
#   {'traditional': '聽任',
#    'simplified': '听任',
#    'pinyin': 'ting1 ren4',
#    'definition': 'to let (sth happen)/to allow (sb to do sth)/to submit to/to yield'},
#   {'traditional': '聽來',
#    'simplified': '听来',
#    'pinyin': 'ting1 lai2',
#    'definition': 'to sound (old, foreign, exciting, right etc)/to ring (true)/to sound as if (i.e. to give the listener an impression)/to hear from somewhere'},
#   {'traditional': '聽信',
#    'simplified': '听信',
#    'pinyin': 'ting1 xin4',
#    'definition': 'to listen to information/to get the news/to believe what one hears'},
#   {'traditional': '聽候',
#    'simplified': '听候',
#    'pinyin': 'ting1 hou4',
#    'definition': 'to wait for (orders, a decision, a judgment)'},
#   {'traditional': '聽友',
#    'simplified': '听友',
#    'pinyin': 'ting1 you3',
#    'definition': 'listener (of a radio program etc)'},
#   {'traditional': '聽取',
#    'simplified': '听取',
#    'pinyin': 'ting1 qu3',
#    'definition': 'to hear (news)/to listen to'},
#   {'traditional': '聽命',
#    'simplified': '听命',
#    'pinyin': 'ting1 ming4',
#    'definition': 'to obey an order/to take orders/to accept a state of affairs'},
#   {'traditional': '聽天由命',
#    'simplified': '听天由命',
#    'pinyin': 'ting1 tian1 you2 ming4',
#    'definition': 'to submit to the will of heaven/to resign oneself to fate/to trust to luck'},
#   {'traditional': '聽寫',
#    'simplified': '听写',
#    'pinyin': 'ting1 xie3',
#    'definition': '(of a pupil) to write down (in a dictation exercise)/dictation/(music) to transcribe by ear'},
#   {'traditional': '聽從',
#    'simplified': '听从',
#    'pinyin': 'ting1 cong2',
#    'definition': 'to listen and obey/to comply with/to heed/to hearken'},
#   {'traditional': '聽憑',
#    'simplified': '听凭',
#    'pinyin': 'ting1 ping2',
#    'definition': 'to allow (sb to do as he pleases)'},
#   {'traditional': '聽懂',
#    'simplified': '听懂',
#    'pinyin': 'ting1 dong3',
#    'definition': 'to understand (on hearing)/to catch (what is spoken)'},
#   {'traditional': '聽戲',
#    'simplified': '听戏',
#    'pinyin': 'ting1 xi4',
#    'definition': 'to attend an opera/to see an opera'},
#   {'traditional': '聽書',
#    'simplified': '听书',
#    'pinyin': 'ting1 shu1',
#    'definition': 'to listen to stories/to listen to performance of 說書|说书 storytelling'},
#   {'traditional': '聽會',
#    'simplified': '听会',
#    'pinyin': 'ting1 hui4',
#    'definition': 'to attend a meeting (and hear what is discussed)'},
#   {'traditional': '聽清',
#    'simplified': '听清',
#    'pinyin': 'ting1 qing1',
#    'definition': 'to hear clearly'},
#   {'traditional': '聽牌',
#    'simplified': '听牌',
#    'pinyin': 'ting1 pai2',
#    'definition': '(mahjong) to be one tile away from completing a hand/(sports) to be on the verge of winning'},
#   {'traditional': '聽眾',
#    'simplified': '听众',
#    'pinyin': 'ting1 zhong4',
#    'definition': 'audience/listeners'},
#   {'traditional': '聽筒',
#    'simplified': '听筒',
#    'pinyin': 'ting1 tong3',
#    'definition': 'telephone receiver/headphone/earphone/earpiece/stethoscope'},
#   {'traditional': '聽者',
#    'simplified': '听者',
#    'pinyin': 'ting1 zhe3',
#    'definition': 'listener/member of audience'},
#   {'traditional': '聽而不聞',
#    'simplified': '听而不闻',
#    'pinyin': 'ting1 er2 bu4 wen2',
#    'definition': 'to hear but not react (idiom); to turn a deaf ear/to ignore deliberately'},
#   {'traditional': '聽聞',
#    'simplified': '听闻',
#    'pinyin': 'ting1 wen2',
#    'definition': 'to listen/to hear what sb says/news one has heard'},
#   {'traditional': '聽覺',
#    'simplified': '听觉',
#    'pinyin': 'ting1 jue2',
#    'definition': 'sense of hearing/auditory'},
#   {'traditional': '聽診器',
#    'simplified': '听诊器',
#    'pinyin': 'ting1 zhen3 qi4',
#    'definition': 'stethoscope'},
#   {'traditional': '聽課',
#    'simplified': '听课',
#    'pinyin': 'ting1 ke4',
#    'definition': 'to attend a class/to go to a lecture'},
#   {'traditional': '聽講',
#    'simplified': '听讲',
#    'pinyin': 'ting1 jiang3',
#    'definition': 'to attend a lecture/to listen to a talk'},
#   {'traditional': '聽證會',
#    'simplified': '听证会',
#    'pinyin': 'ting1 zheng4 hui4',
#    'definition': '(legislative) hearing'},
#   {'traditional': '聽起來',
#    'simplified': '听起来',
#    'pinyin': 'ting1 qi5 lai5',
#    'definition': 'to sound like'},
#   {'traditional': '聽錯',
#    'simplified': '听错',
#    'pinyin': 'ting1 cuo4',
#    'definition': 'to mishear'},
#   {'traditional': '複聽',
#    'simplified': '复听',
#    'pinyin': 'fu4 ting1',
#    'definition': 'double hearing/diplacusis'},
#   {'traditional': '言聽計從',
#    'simplified': '言听计从',
#    'pinyin': 'yan2 ting1 ji4 cong2',
#    'definition': 'to see, hear and obey (idiom); to take advice/to take sb at his word'},
#   {'traditional': '試聽',
#    'simplified': '试听',
#    'pinyin': 'shi4 ting1',
#    'definition': 'audition/to give sb an audition/to check by listening'},
#   {'traditional': '諦聽',
#    'simplified': '谛听',
#    'pinyin': 'di4 ting1',
#    'definition': 'to listen carefully'},
#   {'traditional': '道聽途說',
#    'simplified': '道听途说',
#    'pinyin': 'dao4 ting1 tu2 shuo1',
#    'definition': 'gossip/hearsay/rumor'},
#   {'traditional': '重聽',
#    'simplified': '重听',
#    'pinyin': 'zhong4 ting1',
#    'definition': 'hard of hearing'},
#   {'traditional': '隨身聽',
#    'simplified': '随身听',
#    'pinyin': 'sui2 shen1 ting1',
#    'definition': 'Walkman (trademark)/portable stereo'},
#   {'traditional': '難聽',
#    'simplified': '难听',
#    'pinyin': 'nan2 ting1',
#    'definition': 'unpleasant to hear/coarse/vulgar/offensive/shameful'}]}

# %% [markdown]
# ## Decomposer functions
# Try decomposition levels and component helpers.

# %%
# decompose(character, decomposition_type=None)
# decomposition_type: 1='Once', 2='Radical', 3='Graphical'
decomposer.decompose('爱')

# %%
decomposer.decompose('爱', 2)

# %%
decomposer.decompose('爱', 3)

# %%
# decompose_many() decomposes each char in a string
decomposer.decompose_many('爱橄黃', 2)

# %%
# component_exists() and get_characters_with_component()
decomposer.component_exists('乂'), decomposer.component_exists('$')

# %%
decomposer.get_characters_with_component('囗')[:25]

# %%
# get_radical_meaning() returns a short meaning (when known)
decomposer.get_radical_meaning('氵')
# Out:
# 'water'

# %% [markdown]
# ## Helper: numbered pinyin → tone marks
# If you want tone marks (e.g. `xue3` → `xuě`) you can use this helper.

# %%
TONE_MARKS = {
    'a': ['ā', 'á', 'ǎ', 'à'],
    'e': ['ē', 'é', 'ě', 'è'],
    'i': ['ī', 'í', 'ǐ', 'ì'],
    'o': ['ō', 'ó', 'ǒ', 'ò'],
    'u': ['ū', 'ú', 'ǔ', 'ù'],
    'ü': ['ǖ', 'ǘ', 'ǚ', 'ǜ'],
}

def numbered_pinyin_to_tone_marks(pinyin: str) -> str:
    def convert_syllable(syllable: str) -> str:
        if not syllable:
            return syllable
        syllable = syllable.replace('u:', 'ü').replace('U:', 'Ü')
        tone = 5
        if syllable[-1].isdigit():
            tone = int(syllable[-1])
            syllable = syllable[:-1]
        if tone in (0, 5):
            return syllable
        lower = syllable.lower()
        vowels = 'aeiouü'
        vowel_positions = [i for i, ch in enumerate(lower) if ch in vowels]
        if not vowel_positions:
            return syllable
        mark_index = None
        for v in ('a', 'e'):
            idx = lower.find(v)
            if idx != -1:
                mark_index = idx
                break
        if mark_index is None and 'ou' in lower:
            mark_index = lower.find('o')
        if mark_index is None and 'iu' in lower:
            mark_index = lower.find('u')
        if mark_index is None and 'ui' in lower:
            mark_index = lower.find('i')
        if mark_index is None:
            mark_index = vowel_positions[-1]
        ch = lower[mark_index]
        marked = TONE_MARKS.get(ch, [ch, ch, ch, ch])[tone - 1]
        if syllable[mark_index].isupper():
            marked = marked.upper()
        return syllable[:mark_index] + marked + syllable[mark_index + 1:]
    return ' '.join(convert_syllable(s) for s in pinyin.split())

# Demo
numbered_pinyin_to_tone_marks('xue3'), numbered_pinyin_to_tone_marks('nv3'), numbered_pinyin_to_tone_marks('lu:4')
